# %%
# !git config --global user.email "670405621@qq.com"

# %%
# !git config --global user.name "wangwenkai"

# %%
# !git add .

# %%
# !git commit -m save
# Out:
# [master 6bf13cf] save
#  5 files changed, 186 insertions(+), 67 deletions(-)

# %%
# !git push
# Out:
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 2.45 KiB | 1.22 MiB/s, done.
# Total 7 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 6 local objects.
# To https://github.com/wwkiyyx/deepnote-yolo.git
#    461ff1e..6bf13cf  master -> master

# %%
# !rm -r /root/.ssh
# !mkdir /root/.ssh
# !chmod 600 /root/.ssh
# !cp /work/id_rsa /root/.ssh/
# !cp /work/id_rsa.pub /root/.ssh/
# Out:
# rm: cannot remove '/root/.ssh': No such file or directory

# %%
#!git remote add github git@github.com:wwkiyyx/deepnote-yolo.git
#!git remote add gitee git@gitee.com:wwkiyyx/deepnote-yolo.git
#!git remote add gitcode git@gitcode.net:wangwenkai880510/deepnote-yolo.git
#!git remote add bitbucket git@bitbucket.org:wwkiyyx/deepnote-yolo.git
#!git remote add jihulab git@jihulab.com:wwkiyyx/deepnote-yolo.git
#!git remote add gitlab git@gitlab.com:wwkiyyx/deepnote-yolo.git
# !git remote -v
# Out:
# bitbucket	git@bitbucket.org:wwkiyyx/deepnote-yolo.git (fetch)
# bitbucket	git@bitbucket.org:wwkiyyx/deepnote-yolo.git (push)
# gitcode	git@gitcode.net:wangwenkai880510/deepnote-yolo.git (fetch)
# gitcode	git@gitcode.net:wangwenkai880510/deepnote-yolo.git (push)
# gitee	git@gitee.com:wwkiyyx/deepnote-yolo.git (fetch)
# gitee	git@gitee.com:wwkiyyx/deepnote-yolo.git (push)
# github	git@github.com:wwkiyyx/deepnote-yolo.git (fetch)
# github	git@github.com:wwkiyyx/deepnote-yolo.git (push)
# gitlab	git@gitlab.com:wwkiyyx/deepnote-yolo.git (fetch)
# gitlab	git@gitlab.com:wwkiyyx/deepnote-yolo.git (push)
# jihulab	git@jihulab.com:wwkiyyx/deepnote-yolo.git (fetch)
# jihulab	git@jihulab.com:wwkiyyx/deepnote-yolo.git (push)
# origin	https://github.com/wwkiyyx/deepnote-yolo.git (fetch)
# origin	https://github.com/wwkiyyx/deepnote-yolo.git (push)

# %%
# !git push github master
# Out:
# ...
#
# Everything up-to-date

# %%
# !git push gitee master
# Out:
# ...
#
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 2.45 KiB | 1.22 MiB/s, done.
# Total 7 (delta 6), reused 0 (delta 0)
# remote: Powered by GITEE.COM [GNK-6.3]
# To gitee.com:wwkiyyx/deepnote-yolo.git
#    461ff1e..6bf13cf  master -> master

# %%
# !git push gitcode master
# Out:
# ...
#
# Enumerating objects: 13, done.
# Counting objects: 100% (13/13), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 2.45 KiB | 1.22 MiB/s, done.
# Total 7 (delta 6), reused 0 (delta 0)
# To gitcode.net:wangwenkai880510/deepnote-yolo.git
#    461ff1e..6bf13cf  master -> master

# %%
# !git push bitbucket master
# Out:
# ...
#
# Enumerating objects: 18, done.
# Counting objects: 100% (18/18), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (18/18), done.
# Writing objects: 100% (18/18), 2.98 MiB | 10.07 MiB/s, done.
# Total 18 (delta 8), reused 0 (delta 0)
# To bitbucket.org:wwkiyyx/deepnote-yolo.git
#  * [new branch]      master -> master

# %%
# !git push jihulab master
# Out:
# ...
#
# Enumerating objects: 18, done.
# Counting objects: 100% (18/18), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (18/18), done.
# Writing objects: 100% (18/18), 2.98 MiB | 457.00 KiB/s, done.
# Total 18 (delta 8), reused 0 (delta 0)
# To jihulab.com:wwkiyyx/deepnote-yolo.git
#  * [new branch]      master -> master

# %%
# !git push gitlab master
# Out:
# ...
#
# Enumerating objects: 18, done.
# Counting objects: 100% (18/18), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (18/18), done.
# Writing objects: 100% (18/18), 2.98 MiB | 9.54 MiB/s, done.
# Total 18 (delta 8), reused 0 (delta 0)
# To gitlab.com:wwkiyyx/deepnote-yolo.git
#  * [new branch]      master -> master

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=4c27263b-a773-4b36-bc5c-6cb959f3ea6f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
